# %%
from train import Outliers
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
out = Outliers("./dataset2/testA/")

# %%
result = out.find()
# Out:
# 7it [00:00, 41.11it/s, loss=1.65e+3]
# 7it [00:00, 40.77it/s, loss=1.59e+3]
# 7it [00:00, 41.07it/s, loss=1.36e+3]
# 7it [00:00, 40.83it/s, loss=983]
# 7it [00:00, 40.81it/s, loss=1.4e+3]
# 7it [00:00, 40.61it/s, loss=1.53e+3]
# 7it [00:00, 42.30it/s, loss=-1.73e+3]
# 7it [00:00, 42.64it/s, loss=1.37e+3]
# 7it [00:00, 42.14it/s, loss=1.16e+3]
# 7it [00:00, 42.83it/s, loss=973]
# 7it [00:00, 41.08it/s, loss=1.82e+3]
# 7it [00:00, 41.99it/s, loss=631]
# 7it [00:00, 40.80it/s, loss=-1.3e+4]
# 7it [00:00, 37.95it/s, loss=-2.03e+3]

# %%
result.head(40)
# Out:
#                0                            1
# 102  5577.153326  31Jpg9eC-5L._AC_SY1000_.jpg
# 42   4981.318868           n02381460_1360.jpg
# 13   4411.159937            n02381460_120.jpg
# 47   4323.760391           n02381460_1690.jpg
# 5    4270.682558           n02381460_7250.jpg
# 111  4245.833585             n02381460_50.jpg
# 17   4221.510849           n02381460_3010.jpg
# 116  4175.240024           n02381460_1090.jpg
# 24   4000.915636           n02381460_2710.jpg
# 44   3976.977888           n02381460_2950.jpg
# 55   3670.005393           n02381460_1260.jpg
# 15   3619.969199           n02381460_4800.jpg
# 109  3487.738271           n02381460_1870.jpg
# 93   3466.154019           n02381460_1000.jpg
# 32   3365.557952           n02381460_2650.jpg
# 59   3356.533536           n02381460_6790.jpg
# 107  3330.574788           n02381460_4240.jpg
# 100  3291.881210           n02381460_1660.jpg
# 61   3179.986712            n02381460_640.jpg
# ...

# %%
a = plt.imread("./dataset2/testA/n02381460_1690.jpg", 0)

# %%
plt.imshow(a)
